# %% [markdown]
# <a href="https://colab.research.google.com/github/samuraiinst2025/github-basic-kadai/blob/main/Kadai_001/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HW")
# Out:
# HW
