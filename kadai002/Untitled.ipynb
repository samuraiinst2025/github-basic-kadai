# %% [markdown]
# <a href="https://colab.research.google.com/github/samuraiinst2025/github-basic-kadai/blob/main/kadai002/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HW")
# Out:
# HW

# %%
コードボタンを押すと、このように追加で別のコードが記入できます

# %%
array = [
"月曜日は晴れです",
"火曜日は雨です",
"水曜日は晴れです",
"木曜日は晴れです",
"金曜日は曇りです",
"土曜日は曇りのち雨です",
"日曜日は雷雨です"]

dictionary = {
"mon":"晴れ",
"tue":"雨",
"wed":"水曜日",
"thu":"晴れ",
"fri":"曇り",
"sat":"曇りのち雨",
"sun":"雷雨",
}

print(array[2])
print(f"{dictionary['wed']}は晴れです")
# Out:
# 水曜日は晴れです
# 水曜日は晴れです

# %%
array = [
"月曜日は晴れです",
"火曜日は雨です",
"水曜日は晴れです",
"木曜日は晴れです",
"金曜日は曇りです",
"土曜日は曇りのち雨です",
"日曜日は雷雨です"]

dictionary = {
"mon":"晴れ",
"tue":"雨",
"wed":"水曜日は晴れです",
"thu":"晴れ",
"fri":"曇り",
"sat":"曇りのち雨",
"sun":"雷雨",
}

print(array[2])
print(dictionary["wed"])
